# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, Pool
from sklearn.preprocessing import LabelEncoder
from collections import Counter

# %%
df = pd.read_csv("./data/train_dataset.csv")

# %%
df.head()
# Out:
#                                   domain  length  is_dga
# 0                   tgynbbsiyv-ecfrdt.ru      20       1
# 1  bvokgcwqlnjlieemtthw-homqchjsmqkqg.ba      37       1
# 2                                rkcp.sa       7       1
# 3                   flightbasketball.com      20       0
# 4                lkkogmbqulojf-follow.se      23       1

# %%
df.describe()
# Out:
#              length        is_dga
# count  3.000000e+06  3.000000e+06
# mean   1.627779e+01  6.666670e-01
# std    6.593647e+00  4.714045e-01
# min    4.000000e+00  0.000000e+00
# 25%    1.200000e+01  0.000000e+00
# 50%    1.500000e+01  1.000000e+00
# 75%    1.900000e+01  1.000000e+00
# max    7.300000e+01  1.000000e+00

# %%
df.isna().sum()
# Out:
# domain    0
# length    0
# is_dga    0
# dtype: int64

# %%
df['tld'] = df['domain'].map(lambda x: x.split(".")[-1])

# %%
df.columns
# Out:
# Index(['domain', 'length', 'is_dga', 'tld'], dtype='object')

# %%
df['tld']
# Out:
# 0           ru
# 1           ba
# 2           sa
# 3          com
# 4           se
#           ...
# 2999995     ru
# 2999996     pe
# 2999997     mx
# 2999998     au
# 2999999     za
# Name: tld, Length: 3000000, dtype: object

# %%
df['dash_count'] = df['domain'].map(lambda x: len(x.split('-')) - 1)

# %%
df[df['is_dga'] == 0]
# Out:
#                        domain  length  is_dga  tld  dash_count
# 3        flightbasketball.com      20       0  com           0
# 5                 actouch.com      11       0  com           0
# 7           mideastoffers.com      17       0  com           0
# 12                  1bios.net       9       0  net           0
# 17        ej-technologies.com      19       0  com           1
# ...                       ...     ...     ...  ...         ...
# 2999983         31ventures.jp      13       0   jp           0
# 2999984      hrconnection.com      16       0  com           0
# 2999986       findyoutube.net      15       0  net           0
# 2999993            imh.com.sg      10       0   sg           0
# 2999994              i7gg.com       8       0  com           0
#
# [999999 rows x 5 columns]

# %%
df[df['is_dga'] == 1]
# Out:
#                                         domain  length  is_dga tld  dash_count
# 0                         tgynbbsiyv-ecfrdt.ru      20       1  ru           1
# 1        bvokgcwqlnjlieemtthw-homqchjsmqkqg.ba      37       1  ba           1
# 2                                      rkcp.sa       7       1  sa           0
# 4                      lkkogmbqulojf-follow.se      23       1  se           1
# 6                    oinlgzuwdbeiodnpc-kxej.ad      25       1  ad           1
# ...                                        ...     ...     ...  ..         ...
# 2999995                       mtkdvmusicfde.ru      16       1  ru           0
# 2999996                  rkzanzenncqrn-week.pe      21       1  pe           1
# 2999997       trafficddijjnhtygjyvsfpqwbghv.mx      32       1  mx           0
# 2999998          ncxcbltxvhkyiopufvnp-idbyw.au      29       1  au           1
# 2999999                          kaycybrfhm.za      13       1  za           0
#
# [2000001 rows x 5 columns]

# %%
df['tld_len'] = df['tld'].map(lambda x: len(x))

# %%
# You can count number of n-grams using next formula: max(0, k - n + 1), where's k is length of string, n is length of ngram

# %%
df["2grams"] = df['domain'].map(lambda x: max(0, len(x) - 2 + 1))

# %%
df["3grams"] = df['domain'].map(lambda x: max(0, len(x) - 3 + 1))

# %%
df
# Out:
#                                         domain  length  is_dga  tld  \
# 0                         tgynbbsiyv-ecfrdt.ru      20       1   ru
# 1        bvokgcwqlnjlieemtthw-homqchjsmqkqg.ba      37       1   ba
# 2                                      rkcp.sa       7       1   sa
# 3                         flightbasketball.com      20       0  com
# 4                      lkkogmbqulojf-follow.se      23       1   se
# ...                                        ...     ...     ...  ...
# 2999995                       mtkdvmusicfde.ru      16       1   ru
# 2999996                  rkzanzenncqrn-week.pe      21       1   pe
# 2999997       trafficddijjnhtygjyvsfpqwbghv.mx      32       1   mx
# 2999998          ncxcbltxvhkyiopufvnp-idbyw.au      29       1   au
# 2999999                          kaycybrfhm.za      13       1   za
#
#          dash_count  tld_len  2grams  3grams
# 0                 1        2      19      18
# 1                 1        2      36      35
# 2                 0        2       6       5
# 3                 0        3      19      18
# 4                 1        2      22      21
# ...             ...      ...     ...     ...
# 2999995           0        2      15      14
# 2999996           1        2      20      19
# 2999997           0        2      31      30
# 2999998           1        2      28      27
# 2999999           0        2      12      11
#
# [3000000 rows x 8 columns]

# %%
X = df.drop(['is_dga', "domain"], axis = 1)

# %%
y = df['is_dga']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, shuffle = True)

# %%
train_pool = Pool(X_train, y_train, cat_features = ['tld'])
test_pool = Pool(X_test, y_test, cat_features = ['tld'])

# %%
model = CatBoostClassifier(task_type='GPU',
                           iterations=50,
                           depth=6,
                           learning_rate=0.1,
                           loss_function='CrossEntropy',
                           verbose=True)

# %%
model.fit(train_pool, eval_set = test_pool, use_best_model = True, verbose = True)
# Out:
# 0:	learn: 0.6423019	test: 0.6422793	best: 0.6422793 (0)	total: 16ms	remaining: 782ms
# 1:	learn: 0.6004369	test: 0.6003874	best: 0.6003874 (1)	total: 30.3ms	remaining: 726ms
# 2:	learn: 0.5658209	test: 0.5657497	best: 0.5657497 (2)	total: 44.5ms	remaining: 698ms
# 3:	learn: 0.5370489	test: 0.5369549	best: 0.5369549 (3)	total: 58.8ms	remaining: 677ms
# 4:	learn: 0.4958361	test: 0.4956691	best: 0.4956691 (4)	total: 73.6ms	remaining: 662ms
# 5:	learn: 0.4609034	test: 0.4606474	best: 0.4606474 (5)	total: 88.8ms	remaining: 651ms
# 6:	learn: 0.4311792	test: 0.4308490	best: 0.4308490 (6)	total: 104ms	remaining: 639ms
# 7:	learn: 0.4056459	test: 0.4052704	best: 0.4052704 (7)	total: 120ms	remaining: 630ms
# 8:	learn: 0.3837065	test: 0.3832405	best: 0.3832405 (8)	total: 135ms	remaining: 616ms
# 9:	learn: 0.3647274	test: 0.3641686	best: 0.3641686 (9)	total: 150ms	remaining: 601ms
# 10:	learn: 0.3479827	test: 0.3473356	best: 0.3473356 (10)	total: 165ms	remaining: 586ms
# 11:	learn: 0.3333255	test: 0.3326367	best: 0.3326367 (11)	total: 180ms	remaining: 571ms
# 12:	learn: 0.3203918	test: 0.3196797	best: 0.3196797 (12)	total: 195ms	remaining: 554ms
# 13:	learn: 0.3092911	test: 0.3085067	best: 0.3085067 (13)	total: 210ms	remaining: 539ms
# 14:	learn: 0.2996722	test: 0.2988518	best: 0.2988518 (14)	total: 224ms	remaining: 523ms
# 15:	learn: 0.2909257	test: 0.2900919	best: 0.2900919 (15)	total: 238ms	remaining: 507ms
# 16:	learn: 0.2835682	test: 0.2826585	best: 0.2826585 (16)	total: 253ms	remaining: 490ms
# 17:	learn: 0.2768704	test: 0.2759276	best: 0.2759276 (17)	total: 267ms	remaining: 475ms
# 18:	learn: 0.2707337	test: 0.2697658	best: 0.2697658 (18)	total: 281ms	remaining: 459ms
# 19:	learn: 0.2652023	test: 0.2641997	best: 0.2641997 (19)	total: 296ms	remaining: 444ms
# 20:	learn: 0.2601432	test: 0.2591106	best: 0.2591106 (20)	total: 310ms	remaining: 429ms
# 21:	learn: 0.2556407	test: 0.2546002	best: 0.2546002 (21)	total: 325ms	remaining: 414ms
# 22:	learn: 0.2522253	test: 0.2511327	best: 0.2511327 (22)	total: 339ms	remaining: 398ms
# 23:	learn: 0.2488366	test: 0.2477197	best: 0.2477197 (23)	total: 353ms	remaining: 383ms
# 24:	learn: 0.2454792	test: 0.2443355	best: 0.2443355 (24)	total: 368ms	remaining: 368ms
# 25:	learn: 0.2425023	test: 0.2413412	best: 0.2413412 (25)	total: 383ms	remaining: 353ms
# 26:	learn: 0.2404088	test: 0.2392268	best: 0.2392268 (26)	total: 397ms	remaining: 338ms
# 27:	learn: 0.2378386	test: 0.2366297	best: 0.2366297 (27)	total: 412ms	remaining: 324ms
# 28:	learn: 0.2363667	test: 0.2351284	best: 0.2351284 (28)	total: 426ms	remaining: 308ms
# 29:	learn: 0.2342841	test: 0.2330241	best: 0.2330241 (29)	total: 441ms	remaining: 294ms
# 30:	learn: 0.2325772	test: 0.2312871	best: 0.2312871 (30)	total: 456ms	remaining: 280ms
# 31:	learn: 0.2311770	test: 0.2298944	best: 0.2298944 (31)	total: 471ms	remaining: 265ms
# 32:	learn: 0.2298157	test: 0.2285178	best: 0.2285178 (32)	total: 485ms	remaining: 250ms
# 33:	learn: 0.2285063	test: 0.2271853	best: 0.2271853 (33)	total: 500ms	remaining: 235ms
# 34:	learn: 0.2273446	test: 0.2260070	best: 0.2260070 (34)	total: 515ms	remaining: 221ms
# 35:	learn: 0.2266092	test: 0.2252758	best: 0.2252758 (35)	total: 528ms	remaining: 205ms
# 36:	learn: 0.2256795	test: 0.2243399	best: 0.2243399 (36)	total: 542ms	remaining: 191ms
# 37:	learn: 0.2248861	test: 0.2235352	best: 0.2235352 (37)	total: 556ms	remaining: 176ms
# 38:	learn: 0.2241978	test: 0.2228273	best: 0.2228273 (38)	total: 570ms	remaining: 161ms
# 39:	learn: 0.2235465	test: 0.2221666	best: 0.2221666 (39)	total: 585ms	remaining: 146ms
# 40:	learn: 0.2230075	test: 0.2216139	best: 0.2216139 (40)	total: 599ms	remaining: 131ms
# 41:	learn: 0.2221037	test: 0.2208302	best: 0.2208302 (41)	total: 614ms	remaining: 117ms
# 42:	learn: 0.2215474	test: 0.2203352	best: 0.2203352 (42)	total: 628ms	remaining: 102ms
# 43:	learn: 0.2207145	test: 0.2195004	best: 0.2195004 (43)	total: 643ms	remaining: 87.7ms
# 44:	learn: 0.2200981	test: 0.2189175	best: 0.2189175 (44)	total: 658ms	remaining: 73.1ms
# 45:	learn: 0.2197076	test: 0.2185705	best: 0.2185705 (45)	total: 672ms	remaining: 58.4ms
# 46:	learn: 0.2193199	test: 0.2182229	best: 0.2182229 (46)	total: 686ms	remaining: 43.8ms
# 47:	learn: 0.2187085	test: 0.2176366	best: 0.2176366 (47)	total: 701ms	remaining: 29.2ms
# 48:	learn: 0.2184200	test: 0.2173832	best: 0.2173832 (48)	total: 714ms	remaining: 14.6ms
# 49:	learn: 0.2175682	test: 0.2165683	best: 0.2165683 (49)	total: 729ms	remaining: 0us
# bestTest = 0.2165683125
# bestIteration = 49

# %%
metrics = model.eval_metrics(test_pool, metrics = ['Precision', 'Recall', 'F1', 'AUC'])
precision = metrics['Precision']
recall = metrics['Recall']
f1 = metrics['F1']
auc = metrics['AUC']

# %%
precision[-1]
# Out:
# 0.9177530115006546

# %%
recall[-1]
# Out:
# 0.9492938870219235

# %%
f1[-1]
# Out:
# 0.9332570320573518

# %%
auc[-1]
# Out:
# 0.9677897329055695

# %%
real_df = pd.read_csv("./data/packets_from_pcap.csv", encoding_errors = 'ignore')
# Out:
# C:\Users\alons\AppData\Local\Temp\ipykernel_10044\2651594118.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   real_df = pd.read_csv("./data/packets_from_pcap.csv", encoding_errors = 'ignore')

# %%
real_df.isna().sum()
# Out:
# No.                  0
# Time                 0
# Source               0
# Destination          0
# Length               0
# Name           4163241
# Name Length    4163241
# dtype: int64

# %%
real_df = real_df.dropna()

# %%
real_df
# Out:
#              No.          Time          Source     Destination  Length  \
# 835          836  1.083720e+03  192.168.200.90  37.221.193.103      73
# 836          837  1.087156e+03  192.168.200.90  37.221.193.103      73
# 837          838  1.091741e+03  192.168.200.90  37.221.193.103      73
# 840          841  1.100282e+03  192.168.200.90  37.221.193.103      73
# 841          842  1.118605e+03  192.168.200.90  37.221.193.103      73
# ...          ...           ...             ...             ...     ...
# 7624591  7624592  5.054352e+07    10.250.18.22       20.2.7.51     115
# 7624592  7624593  5.054352e+07      47.5.99.35    10.250.33.37     379
# 7624594  7624595  5.054352e+07    10.250.23.27   93.184.216.34     379
# 7624596  7624597  5.054352e+07    10.250.33.37       42.2.5.24     379
# 7624597  7624598  5.054352e+07      10.250.4.8      71.87.35.6     379
#
#                              Name Name Length
# 835                     grafin.ru         9.0
# 836                     grafin.ru         9.0
# 837                     grafin.ru         9.0
# 840                     grafin.ru         9.0
# 841                     grafin.ru         9.0
# ...                           ...         ...
# 7624591  <Unknown extended label>          24
# 7624592  <Unknown extended label>          24
# 7624594  <Unknown extended label>          24
# 7624596  <Unknown extended label>          24
# 7624597  <Unknown extended label>          24
#
# [3461361 rows x 7 columns]

# %%
real_df = real_df.drop(["No.", "Time"], axis = 1)

# %%
real_df
# Out:
#                  Source     Destination  Length                      Name  \
# 835      192.168.200.90  37.221.193.103      73                 grafin.ru
# 836      192.168.200.90  37.221.193.103      73                 grafin.ru
# 837      192.168.200.90  37.221.193.103      73                 grafin.ru
# 840      192.168.200.90  37.221.193.103      73                 grafin.ru
# 841      192.168.200.90  37.221.193.103      73                 grafin.ru
# ...                 ...             ...     ...                       ...
# 7624591    10.250.18.22       20.2.7.51     115  <Unknown extended label>
# 7624592      47.5.99.35    10.250.33.37     379  <Unknown extended label>
# 7624594    10.250.23.27   93.184.216.34     379  <Unknown extended label>
# 7624596    10.250.33.37       42.2.5.24     379  <Unknown extended label>
# 7624597      10.250.4.8      71.87.35.6     379  <Unknown extended label>
#
#         Name Length
# 835             9.0
# 836             9.0
# 837             9.0
# 840             9.0
# 841             9.0
# ...             ...
# 7624591          24
# 7624592          24
# 7624594          24
# 7624596          24
# 7624597          24
#
# [3461361 rows x 5 columns]

# %%
real_df = real_df[real_df["Name"] != "<Unknown extended label>"]

# %%
real_df
# Out:
#                             Source     Destination  Length  \
# 835                 192.168.200.90  37.221.193.103      73
# 836                 192.168.200.90  37.221.193.103      73
# 837                 192.168.200.90  37.221.193.103      73
# 840                 192.168.200.90  37.221.193.103      73
# 841                 192.168.200.90  37.221.193.103      73
# ...                            ...             ...     ...
# 7602912               10.10.15.122     224.0.0.251     119
# 7602913  fe80::3028:8aff:fe08:f2dd        ff02::fb     139
# 7605614  fe80::6e30:c1ca:8206:6a95        ff02::fb     105
# 7607600                10.10.15.31     224.0.0.251      85
# 7607601  fe80::32bd:c8c4:a552:1f97        ff02::fb     105
#
#                                                       Name Name Length
# 835                                              grafin.ru         9.0
# 836                                              grafin.ru         9.0
# 837                                              grafin.ru         9.0
# 840                                              grafin.ru         9.0
# 841                                              grafin.ru         9.0
# ...                                                    ...         ...
# 7602912  _674A0243._sub._googlecast._tcp.local,_8E6C866...    37,37,22
# 7602913  _674A0243._sub._googlecast._tcp.local,_8E6C866...    37,37,22
# 7605614                          _microsoft_mcc._tcp.local          25
# 7607600                          _microsoft_mcc._tcp.local          25
# 7607601                          _microsoft_mcc._tcp.local          25
#
# [3210155 rows x 5 columns]

# %%
real_df = real_df.drop(real_df[real_df["Name Length"].str.count(',') > 0].index)

# %%
real_df
# Out:
#                             Source     Destination  Length  \
# 835                 192.168.200.90  37.221.193.103      73
# 836                 192.168.200.90  37.221.193.103      73
# 837                 192.168.200.90  37.221.193.103      73
# 840                 192.168.200.90  37.221.193.103      73
# 841                 192.168.200.90  37.221.193.103      73
# ...                            ...             ...     ...
# 7572877                10.10.15.53     224.0.0.251      73
# 7574410                10.10.15.53     224.0.0.251      67
# 7605614  fe80::6e30:c1ca:8206:6a95        ff02::fb     105
# 7607600                10.10.15.31     224.0.0.251      85
# 7607601  fe80::32bd:c8c4:a552:1f97        ff02::fb     105
#
#                               Name Name Length
# 835                      grafin.ru         9.0
# 836                      grafin.ru         9.0
# 837                      grafin.ru         9.0
# 840                      grafin.ru         9.0
# 841                      grafin.ru         9.0
# ...                            ...         ...
# 7572877              w-me-10.local          13
# 7574410                    w-me-10           7
# 7605614  _microsoft_mcc._tcp.local          25
# 7607600  _microsoft_mcc._tcp.local          25
# 7607601  _microsoft_mcc._tcp.local          25
#
# [3204094 rows x 5 columns]

# %%
real_df['tld'] = real_df['Name'].map(lambda x: x.split(".")[-1])

# %%
real_df['dash_count'] = real_df['Name'].map(lambda x: len(x.split('-')) - 1)

# %%
real_df['tld_len'] = real_df['tld'].map(lambda x: len(x))

# %%
real_df["2grams"] = real_df['Name'].map(lambda x: max(0, len(x) - 2 + 1))

# %%
real_df["3grams"] = real_df['Name'].map(lambda x: max(0, len(x) - 3 + 1))

# %%
real_df
# Out:
#                             Source     Destination  Length  \
# 835                 192.168.200.90  37.221.193.103      73
# 836                 192.168.200.90  37.221.193.103      73
# 837                 192.168.200.90  37.221.193.103      73
# 840                 192.168.200.90  37.221.193.103      73
# 841                 192.168.200.90  37.221.193.103      73
# ...                            ...             ...     ...
# 7572877                10.10.15.53     224.0.0.251      73
# 7574410                10.10.15.53     224.0.0.251      67
# 7605614  fe80::6e30:c1ca:8206:6a95        ff02::fb     105
# 7607600                10.10.15.31     224.0.0.251      85
# 7607601  fe80::32bd:c8c4:a552:1f97        ff02::fb     105
#
#                               Name Name Length      tld  dash_count  tld_len  \
# 835                      grafin.ru         9.0       ru           0        2
# 836                      grafin.ru         9.0       ru           0        2
# 837                      grafin.ru         9.0       ru           0        2
# 840                      grafin.ru         9.0       ru           0        2
# 841                      grafin.ru         9.0       ru           0        2
# ...                            ...         ...      ...         ...      ...
# 7572877              w-me-10.local          13    local           2        5
# 7574410                    w-me-10           7  w-me-10           2        7
# 7605614  _microsoft_mcc._tcp.local          25    local           0        5
# 7607600  _microsoft_mcc._tcp.local          25    local           0        5
# 7607601  _microsoft_mcc._tcp.local          25    local           0        5
#
#          2grams  3grams
# 835           8       7
# 836           8       7
# 837           8       7
# 840           8       7
# 841           8       7
# ...         ...     ...
# 7572877      12      11
# 7574410       6       5
# 7605614      24      23
# 7607600      24      23
# 7607601      24      23
#
# [3204094 rows x 10 columns]

# %%
real_df = real_df.rename(columns={"Name Length": "length"})

# %%
real_df
# Out:
#                             Source     Destination  Length  \
# 835                 192.168.200.90  37.221.193.103      73
# 836                 192.168.200.90  37.221.193.103      73
# 837                 192.168.200.90  37.221.193.103      73
# 840                 192.168.200.90  37.221.193.103      73
# 841                 192.168.200.90  37.221.193.103      73
# ...                            ...             ...     ...
# 7572877                10.10.15.53     224.0.0.251      73
# 7574410                10.10.15.53     224.0.0.251      67
# 7605614  fe80::6e30:c1ca:8206:6a95        ff02::fb     105
# 7607600                10.10.15.31     224.0.0.251      85
# 7607601  fe80::32bd:c8c4:a552:1f97        ff02::fb     105
#
#                               Name length      tld  dash_count  tld_len  \
# 835                      grafin.ru    9.0       ru           0        2
# 836                      grafin.ru    9.0       ru           0        2
# 837                      grafin.ru    9.0       ru           0        2
# 840                      grafin.ru    9.0       ru           0        2
# 841                      grafin.ru    9.0       ru           0        2
# ...                            ...    ...      ...         ...      ...
# 7572877              w-me-10.local     13    local           2        5
# 7574410                    w-me-10      7  w-me-10           2        7
# 7605614  _microsoft_mcc._tcp.local     25    local           0        5
# 7607600  _microsoft_mcc._tcp.local     25    local           0        5
# 7607601  _microsoft_mcc._tcp.local     25    local           0        5
#
#          2grams  3grams
# 835           8       7
# 836           8       7
# 837           8       7
# 840           8       7
# 841           8       7
# ...         ...     ...
# 7572877      12      11
# 7574410       6       5
# 7605614      24      23
# 7607600      24      23
# 7607601      24      23
#
# [3204094 rows x 10 columns]

# %%
model

# %%
X = real_df.drop(["Source", "Destination", "Length", "Name"], axis = 1)

# %%
X
# Out:
#         length      tld  dash_count  tld_len  2grams  3grams
# 835        9.0       ru           0        2       8       7
# 836        9.0       ru           0        2       8       7
# 837        9.0       ru           0        2       8       7
# 840        9.0       ru           0        2       8       7
# 841        9.0       ru           0        2       8       7
# ...        ...      ...         ...      ...     ...     ...
# 7572877     13    local           2        5      12      11
# 7574410      7  w-me-10           2        7       6       5
# 7605614     25    local           0        5      24      23
# 7607600     25    local           0        5      24      23
# 7607601     25    local           0        5      24      23
#
# [3204094 rows x 6 columns]

# %%
test_data_ = Pool(X, cat_features = ['tld'])

# %%
model.predict(test_data_)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], shape=(3204094,))

# %%
real_df["is_dga"] = model.predict(test_data_)

# %%
real_df[real_df["is_dga"] == 0]
# Out:
#                            Source     Destination  Length  \
# 835                192.168.200.90  37.221.193.103      73
# 836                192.168.200.90  37.221.193.103      73
# 837                192.168.200.90  37.221.193.103      73
# 840                192.168.200.90  37.221.193.103      73
# 841                192.168.200.90  37.221.193.103      73
# ...                           ...             ...     ...
# 7506179                10.10.16.1     10.10.15.56     122
# 7506342               10.10.15.56      10.10.16.1      91
# 7506365               10.10.15.56      10.10.16.1      90
# 7558806              10.10.15.233     224.0.0.251      95
# 7558807  fe80::c67:b0e3:e0dd:996a        ff02::fb     115
#
#                                         Name length    tld  dash_count  \
# 835                                grafin.ru    9.0     ru           0
# 836                                grafin.ru    9.0     ru           0
# 837                                grafin.ru    9.0     ru           0
# 840                                grafin.ru    9.0     ru           0
# 841                                grafin.ru    9.0     ru           0
# ...                                      ...    ...    ...         ...
# 7506179       dual-spov-0006.spov-msedge.net     30    net           3
# 7506342      my.microsoftpersonalcontent.com     31    com           0
# 7506365       dual-spov-0006.spov-msedge.net     30    net           3
# 7558806  PRO-223T._companion-link._tcp.local     35  local           2
# 7558807  PRO-223T._companion-link._tcp.local     35  local           2
#
#          tld_len  2grams  3grams  is_dga
# 835            2       8       7       0
# 836            2       8       7       0
# 837            2       8       7       0
# 840            2       8       7       0
# 841            2       8       7       0
# ...          ...     ...     ...     ...
# 7506179        3      29      28       0
# 7506342        3      30      29       0
# 7506365        3      29      28       0
# 7558806        5      34      33       0
# 7558807        5      34      33       0
#
# [1992406 rows x 11 columns]

# %%
df_to_save = real_df.drop(["Length", "length", "tld", "dash_count", "tld_len", "2grams", "3grams"], axis = 1)

# %%
df_to_save
# Out:
#                             Source     Destination                       Name  \
# 835                 192.168.200.90  37.221.193.103                  grafin.ru
# 836                 192.168.200.90  37.221.193.103                  grafin.ru
# 837                 192.168.200.90  37.221.193.103                  grafin.ru
# 840                 192.168.200.90  37.221.193.103                  grafin.ru
# 841                 192.168.200.90  37.221.193.103                  grafin.ru
# ...                            ...             ...                        ...
# 7572877                10.10.15.53     224.0.0.251              w-me-10.local
# 7574410                10.10.15.53     224.0.0.251                    w-me-10
# 7605614  fe80::6e30:c1ca:8206:6a95        ff02::fb  _microsoft_mcc._tcp.local
# 7607600                10.10.15.31     224.0.0.251  _microsoft_mcc._tcp.local
# 7607601  fe80::32bd:c8c4:a552:1f97        ff02::fb  _microsoft_mcc._tcp.local
#
#          is_dga
# 835           0
# 836           0
# 837           0
# 840           0
# 841           0
# ...         ...
# 7572877       1
# 7574410       1
# 7605614       1
# 7607600       1
# 7607601       1
#
# [3204094 rows x 4 columns]

# %%
df_to_save.to_csv("./solution.csv")
